# %%
import pandas as pd

# %%
cluster5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_cluster5.csv", encoding="EUC-KR")
starbucks_group1 = cluster5['cluster'] == 1
starbucks_group1 = cluster5[starbucks_group1]
starbucks_group1.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_group1.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
cluster5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_cluster5.csv", encoding="EUC-KR")
starbucks_group0 = cluster5['cluster'] == 0
starbucks_group0 = cluster5[starbucks_group0]
starbucks_group0.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_group0.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
cluster5
# Out:
#      Unnamed: 0 store_name  유동인구_평균_x     차선수_x  bus_cnt  sbstn  cluster  \
# 0             0       KG타워      24141  4.000000        6      0        0
# 1             1   SSG마켓도곡R      30953  4.000000       10      1        0
# 2             2      가락시장역      37909  2.666667        8      1        4
# 3             3     가재울뉴타운      20391  2.000000       10      0        1
# 4             4        강남R      97922  4.000000       16      1        3
# ..          ...        ...        ...       ...      ...    ...      ...
# 289         289        화곡동      47359  3.000000        8      1        4
# 290         290        환구단      24141  3.000000       12      1        2
# 291         291      황학사거리      30053  1.600000        9      0        1
# 292         292       황학캐슬      12939  2.000000        7      0        1
# 293         293     효창공원앞역      10216  3.000000        9      1        2
#
#           LINK_ID      lat_x       lot_x  ...       15시       16시       17시  \
# ...

# %%
weekday_mean = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\weekday_mean.csv", encoding="EUC-KR")

# %%
cluster5_prep = pd.merge(left=cluster5, right=weekday_mean, how='left', left_on='store_name', right_on='store_name')

# %%
cluster5_prep
# Out:
#     store_name  유동인구_평균_x     차선수_x  bus_cnt  sbstn  cluster       LINK_ID  \
# 0         KG타워      24141  4.000000        6      0        0  1.010009e+09
# 1     SSG마켓도곡R      30953  4.000000       10      1        0  1.220014e+09
# 2        가락시장역      37909  2.666667        8      1        4  1.230010e+09
# 3       가재울뉴타운      20391  2.000000       10      0        1  1.120008e+09
# 4          강남R      97922  4.000000       16      1        3  1.220023e+09
# ..         ...        ...       ...      ...    ...      ...           ...
# 289        화곡동      47359  3.000000        8      1        4  1.140038e+09
# 290        환구단      24141  3.000000       12      1        2  1.010010e+09
# 291      황학사거리      30053  1.600000        9      0        1  1.018018e+09
# 292       황학캐슬      12939  2.000000        7      0        1  1.010019e+09
# 293     효창공원앞역      10216  3.000000        9      1        2  1.020014e+09
#
# ...

# %%
cluster5_prep.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\cluster5_prep.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
cluster5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\cluster5_prep.csv", encoding="EUC-KR")
starbucks_group0 = cluster5['cluster'] == 0
starbucks_group0 = cluster5[starbucks_group0]
starbucks_group0.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_group0_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
cluster5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\cluster5_prep.csv", encoding="EUC-KR")
starbucks_group1 = cluster5['cluster'] == 1
starbucks_group1 = cluster5[starbucks_group1]
starbucks_group1.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_group1_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
weekend_mean = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\weekend_mean.csv", encoding="EUC-KR")

# %%
cluster5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_cluster5.csv", encoding="EUC-KR")

# %%
cluster5
# Out:
#     store_name  유동인구_평균       차선수  bus_cnt  sbstn  cluster
# 0         KG타워    24141  4.000000        6      0        0
# 1     SSG마켓도곡R    30953  4.000000       10      1        0
# 2        가락시장역    37909  2.666667        8      1        4
# 3       가재울뉴타운    20391  2.000000       10      0        1
# 4          강남R    97922  4.000000       16      1        3
# ..         ...      ...       ...      ...    ...      ...
# 289        화곡동    47359  3.000000        8      1        4
# 290        환구단    24141  3.000000       12      1        2
# 291      황학사거리    30053  1.600000        9      0        1
# 292       황학캐슬    12939  2.000000        7      0        1
# 293     효창공원앞역    10216  3.000000        9      1        2
#
# [294 rows x 6 columns]

# %%
cluster5_prep = pd.merge(left=cluster5, right=weekend_mean, how='left', left_on='store_name', right_on='store_name')

# %%
cluster5_prep
# Out:
#     store_name  유동인구_평균_x     차선수_x  bus_cnt  sbstn  cluster       LINK_ID  \
# 0         KG타워      24141  4.000000        6      0        0  1.010009e+09
# 1     SSG마켓도곡R      30953  4.000000       10      1        0  1.220014e+09
# 2        가락시장역      37909  2.666667        8      1        4  1.230010e+09
# 3       가재울뉴타운      20391  2.000000       10      0        1  1.120008e+09
# 4          강남R      97922  4.000000       16      1        3  1.220023e+09
# ..         ...        ...       ...      ...    ...      ...           ...
# 289        화곡동      47359  3.000000        8      1        4  1.140038e+09
# 290        환구단      24141  3.000000       12      1        2  1.010010e+09
# 291      황학사거리      30053  1.600000        9      0        1  1.018018e+09
# 292       황학캐슬      12939  2.000000        7      0        1  1.010019e+09
# 293     효창공원앞역      10216  3.000000        9      1        2  1.020014e+09
#
# ...

# %%
starbucks_group0 = cluster5_prep['cluster'] == 0
starbucks_group0 = cluster5_prep[starbucks_group0]
starbucks_group0.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_group0_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group1 = cluster5_prep['cluster'] == 1
starbucks_group1 = cluster5_prep[starbucks_group1]
starbucks_group1.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\agg_group1_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')
