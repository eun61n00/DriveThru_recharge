# %%
import pandas as pd

# %%
starbucks_point = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\starbucks_info\starbucks_info.csv", encoding="EUC-KR")

# %%
starbucks_point
# Out:
#     store_name                                         store_addr        lat  \
# 0      역삼아레나빌딩                   서울특별시 강남구 언주로 425 (역삼동)1522-3232  37.501087
# 1       논현역사거리                  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2      신사역성일빌딩                  서울특별시 강남구 강남대로 584 (논현동)1522-3232  37.514132
# 3       국기원사거리                  서울특별시 강남구 테헤란로 125 (역삼동)1522-3232  37.499517
# 4       스탈릿대치R                서울특별시 강남구 남부순환로 2947 (대치동)1522-3232  37.494668
# ..         ...                                                ...        ...
# 551       사가정역                         서울특별시 중랑구 면목로 3101522-3232  37.579594
# 552        상봉역                   서울특별시 중랑구 망우로 307 (상봉동)1522-3232  37.596890
# 553      묵동이마트  서울특별시 중랑구 동일로 932 (묵동, 묵동자이아파트) (묵동이마트 B1층)152...  37.613433
# 554         묵동                        서울특별시 중랑구 동일로 952 1522-3232  37.615368
# 555        중화역                    서울특별시 중랑구 봉화산로 35 1,2층1522-3232  37.601709
#
#             lot     도로    길
# ...

# %%
road_ext_50m = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\50m\50m.csv", encoding="EUC-KR")

# %%
road_ext_50m
# Out:
#         LINK_ID  begin  end store_name  \
# 0    1110008106      1   13     은평구청입구
# 1    1130019501      1   16        아현역
# 2    1130026401      1    2    상암디지털큐브
# 3    1130026402      1    2      상암DMC
# 4    1130072000      1    2      상암YTN
# ..          ...    ...  ...        ...
# 512  1130000600      1    3      마포아크로
# 513  1220004300      1    4     청담영동대로
# 514  1230029300      1    3      몽촌토성역
# 515  1230028100      1    3    올림픽평화의문
# 516  1230026100      1    3    올림픽공원남문
#
#                                             store_addr        lat         lot  \
# 0                     서울특별시 은평구 은평로 170 (응암동)1522-3232  37.601042  126.926789
# 1    서울특별시 서대문구 신촌로35길 10 (북아현동, E편한세상신촌 4단지)1522-3232  37.558421  126.956349
# 2                           서울특별시 마포구 상암산로 341522-3232  37.576313  126.889248
# 3    서울특별시 마포구 월드컵북로 375, DMC이안오피스텔1단지 102호,202호 (상...  37.577623  126.890684
# 4                     서울특별시 마포구 상암산로 76 (상암동)1522-3232  37.579183  126.892315
# ...

# %%
road_join_fullstore = pd.merge(left=starbucks_point, right=road_ext_50m, how='left', left_on='store_name', right_on='store_name')

# %%
road_join_fullstore.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\road_join_fullstore.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_join_fullstore[:10]
# Out:
#   store_name                         store_addr_x      lat_x       lot_x  \
# 0    역삼아레나빌딩     서울특별시 강남구 언주로 425 (역삼동)1522-3232  37.501087  127.043069
# 1     논현역사거리    서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178  127.022223
# 2    신사역성일빌딩    서울특별시 강남구 강남대로 584 (논현동)1522-3232  37.514132  127.020563
# 3     국기원사거리    서울특별시 강남구 테헤란로 125 (역삼동)1522-3232  37.499517  127.031495
# 4     스탈릿대치R  서울특별시 강남구 남부순환로 2947 (대치동)1522-3232  37.494668  127.062583
# 5     스탈릿대치R  서울특별시 강남구 남부순환로 2947 (대치동)1522-3232  37.494668  127.062583
# 6       봉은사역    서울특별시 강남구 봉은사로 619 (삼성동)1522-3232  37.515000  127.063196
# 7    압구정윤성빌딩     서울특별시 강남구 논현로 834 (신사동)1522-3232  37.522793  127.028601
# 8     코엑스별마당    서울특별시 강남구 영동대로 513 (삼성동)1522-3232  37.510150  127.060275
# 9   삼성역섬유센터R    서울특별시 강남구 테헤란로 518 (대치동)1522-3232  37.507750  127.060651
#
#     도로_x  길_x       LINK_ID  begin  end                         store_addr_y  \
# 0    언주로  NaN  1.220025e+09    1.0  4.0     서울특별시 강남구 언주로 425 (역삼동)1522-3232
# ...

# %%
no_road = road_join_fullstore['LINK_ID'].isnull()
no_road = road_join_fullstore[no_road]
no_road.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\no_road.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
no_road[:10]
# Out:
#    store_name                                 store_addr_x      lat_x  \
# 8      코엑스별마당            서울특별시 강남구 영동대로 513 (삼성동)1522-3232  37.510150
# 15      강남오거리           서울특별시 강남구 봉은사로2길 39 (역삼동)1522-3232  37.502117
# 16  스타필드코엑스몰R  서울특별시 강남구 영동대로 513 (삼성동) 코엑스 A106호1522-3232  37.509990
# 23        압구정          서울특별시 강남구 압구정로30길 17 (신사동)1522-3232  37.526283
# 24      신사가로수                  서울특별시 강남구 가로수길 59 1522-3232  37.521933
# 25      청담스타R          서울특별시 강남구 도산대로57길 24 (청담동)1522-3232  37.525216
# 35      청담사거리       서울특별시 강남구 도산대로 458 (청담동) 리츠타워1522-3232  37.523635
# 40       코엑스몰      서울특별시 강남구 영동대로 513 (삼성동) O103호1522-3232  37.513715
# 47     삼성도심공항          서울특별시 강남구 테헤란로87길 33 (삼성동)1522-3232  37.509786
# 48        삼성교     서울특별시 강남구 영동대로86길 12, 동남유화빌딩 1층1522-3232  37.507794
#
#          lot_x     도로_x  길_x  LINK_ID  begin  end store_addr_y  lat_y  lot_y  \
# 8   127.060275     영동대로  NaN      NaN    NaN  NaN          NaN    NaN    NaN
# ...

# %%
road_ext_50m = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\50m\50m.csv", encoding="EUC-KR")

# %%
road_ext_3050m = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\50+30\sb+id_ver2.csv", encoding="EUC-KR")

# %%
road_ext_3050m
# Out:
#     store_name  is_dt     link_id     link_id_2  차선수    07시    08시    09시  \
# 0      역삼아레나빌딩      0  1220024600           NaN    4  25.16  23.11  21.11
# 1       논현역사거리      0  1220027900           NaN    4  28.25  26.42  23.22
# 2      신사역성일빌딩      0  1220030700           NaN    4  30.33  27.59  25.66
# 3       국기원사거리      0  1220024000  1.220023e+09    4  36.43  29.90  27.30
# 4       스탈릿대치R      0  1220018400  1.220022e+09    4  37.62  28.29  18.97
# ..         ...    ...         ...           ...  ...    ...    ...    ...
# 427        상봉역      0  1060002100           NaN    2  28.34  23.86  19.29
# 428      묵동이마트      0  1060005100           NaN    3  30.25  25.89  24.56
# 429         묵동      0  1060005100  1.060020e+09    3  30.25  25.89  24.56
# 430        중화역      0  1060015100           NaN    2  25.04  21.44  18.29
# 431    신월IC DT      1  1140023300           NaN    3  38.14  23.92  20.25
#
#        10시    11시  ...  second_12시  second_13시  second_14시  second_15시  \
# ...

# %%
test_join = pd.merge(left=road_ext_50m, right=road_ext_3050m, how='left', left_on='store_name', right_on='store_name')

# %%
test_join.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\test_join.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_ext_50m
# Out:
#         LINK_ID  begin  end store_name  \
# 0    1110008106      1   13     은평구청입구
# 1    1130019501      1   16        아현역
# 2    1130026401      1    2    상암디지털큐브
# 3    1130026402      1    2      상암DMC
# 4    1130072000      1    2      상암YTN
# ..          ...    ...  ...        ...
# 505  1130000600      1    3      마포아크로
# 506  1220004300      1    4     청담영동대로
# 507  1230029300      1    3      몽촌토성역
# 508  1230028100      1    3    올림픽평화의문
# 509  1230026100      1    3    올림픽공원남문
#
#                                             store_addr        lat         lot  \
# 0                     서울특별시 은평구 은평로 170 (응암동)1522-3232  37.601042  126.926789
# 1    서울특별시 서대문구 신촌로35길 10 (북아현동, E편한세상신촌 4단지)1522-3232  37.558421  126.956349
# 2                           서울특별시 마포구 상암산로 341522-3232  37.576313  126.889248
# 3    서울특별시 마포구 월드컵북로 375, DMC이안오피스텔1단지 102호,202호 (상...  37.577623  126.890684
# 4                     서울특별시 마포구 상암산로 76 (상암동)1522-3232  37.579183  126.892315
# ...

# %%
list = set(road_ext_50m['store_name'])

# %%
len(list)
# Out:
# 400

# %%
bus_sub = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\bus_sub.csv", encoding="EUC-KR")

# %%
bus_sub
# Out:
#         LINK_ID store_name                                         store_addr  \
# 0    1110008106     은평구청입구                   서울특별시 은평구 은평로 170 (응암동)1522-3232
# 1    1130019501        아현역  서울특별시 서대문구 신촌로35길 10 (북아현동, E편한세상신촌 4단지)1522-3232
# 2    1130026401    상암디지털큐브                         서울특별시 마포구 상암산로 341522-3232
# 3    1130026402      상암DMC  서울특별시 마포구 월드컵북로 375, DMC이안오피스텔1단지 102호,202호 (상...
# 4    1130072000      상암YTN                   서울특별시 마포구 상암산로 76 (상암동)1522-3232
# ..          ...        ...                                                ...
# 470  1130000600      마포아크로           서울특별시 마포구 마포대로 68 (도화동) 마포아크로타워1522-3232
# 471  1220004300     청담영동대로                  서울특별시 강남구 영동대로 720 (청담동)1522-3232
# 472  1230029300      몽촌토성역                        서울특별시 송파구 위례성대로 6 1522-3232
# 473  1230028100    올림픽평화의문        서울특별시 송파구 위례성대로 38 (방이동) 해태그린피아빌라트1522-3232
# 474  1230026100    올림픽공원남문                 서울특별시 송파구 위례성대로 102 (방이동)1522-3232
#
#      bus_cnt  substn
# ...

# %%
pop = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\starbucks_join_pop.csv", encoding="EUC-KR")

# %%
pop
# Out:
#     store_name  지역  구로구     동    도로  유동인구_평균        lat         lot
# 0      역삼아레나빌딩  서울  강남구  역삼2동   언주로    52263  37.501087  127.043069
# 1         도곡공원  서울  강남구  역삼2동   도곡로    52263  37.492805  127.041309
# 2        역삼이마트  서울  강남구  역삼2동   역삼로    52263  37.499367  127.048425
# 3       논현역사거리  서울  강남구  논현1동  강남대로    41326  37.510178  127.022223
# 4      신사역성일빌딩  서울  강남구  논현1동  강남대로    41326  37.514132  127.020563
# ..         ...  ..  ...   ...   ...      ...        ...         ...
# 551       사가정역  서울  중랑구  면목7동   면목로    20503  37.579594  127.087966
# 552        상봉역  서울  중랑구  상봉1동   망우로    18510  37.596890  127.086470
# 553      묵동이마트  서울  중랑구   묵1동   동일로    26575  37.613433  127.077484
# 554         묵동  서울  중랑구   묵1동   동일로    26575  37.615368  127.076633
# 555        중화역  서울  중랑구  중화2동  봉화산로    26002  37.601709  127.078411
#
# [556 rows x 8 columns]

# %%
v = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\202107_v.csv", encoding="EUC-KR")

# %%
v = v[:5034]
v
# Out:
#             일자 요일    도로명       링크아이디         시점명         종점명  방향    거리  차선수  \
# 0     20210701  목  4.19로  1080012200     아카데미하우스    국립4.19묘지  상행  1179    1
# 1     20210701  목  4.19로  1080012800    국립4.19묘지  국립4.19묘지입구  상행   352    2
# 2     20210701  목  4.19로  1080012700  국립4.19묘지입구    국립4.19묘지  하행   354    2
# 3     20210701  목  4.19로  1080012100    국립4.19묘지     아카데미하우스  하행  1190    1
# 4     20210701  목    가락로  1230024700        방이초교      방이동고분군  상행   844    1
# ...        ... ..    ...         ...         ...         ...  ..   ...  ...
# 5029  20210701  목    흑석로  1190003703       중앙대학교        성심의집  하행   398    0
# 5030  20210701  목    흑석로  1190003702        성심의집        이화빌라  하행   143    0
# 5031  20210701  목    흑석로  1190003701        이화빌라        이화약국  하행   133    0
# 5032  20210701  목   희우정로  1130016400      망원정사거리      한강공원입구  상행   692    2
# 5033  20210701  목   희우정로  1130016300      한강공원입구      망원정사거리  하행   688    2
#
# ...

# %%
cnt_pop = pd.merge(left=bus_sub, right=pop, how='left', left_on='store_name', right_on='store_name')

# %%
cnt_pop
# Out:
#         LINK_ID store_name                                         store_addr  \
# 0    1110008106     은평구청입구                   서울특별시 은평구 은평로 170 (응암동)1522-3232
# 1    1130019501        아현역  서울특별시 서대문구 신촌로35길 10 (북아현동, E편한세상신촌 4단지)1522-3232
# 2    1130026401    상암디지털큐브                         서울특별시 마포구 상암산로 341522-3232
# 3    1130026402      상암DMC  서울특별시 마포구 월드컵북로 375, DMC이안오피스텔1단지 102호,202호 (상...
# 4    1130072000      상암YTN                   서울특별시 마포구 상암산로 76 (상암동)1522-3232
# ..          ...        ...                                                ...
# 470  1130000600      마포아크로           서울특별시 마포구 마포대로 68 (도화동) 마포아크로타워1522-3232
# 471  1220004300     청담영동대로                  서울특별시 강남구 영동대로 720 (청담동)1522-3232
# 472  1230029300      몽촌토성역                        서울특별시 송파구 위례성대로 6 1522-3232
# 473  1230028100    올림픽평화의문        서울특별시 송파구 위례성대로 38 (방이동) 해태그린피아빌라트1522-3232
# 474  1230026100    올림픽공원남문                 서울특별시 송파구 위례성대로 102 (방이동)1522-3232
#
# ...

# %%
cnt_pop_v = pd.merge(left=cnt_pop, right=v, how='left', left_on='LINK_ID', right_on='링크아이디')

# %%
cnt_pop_v.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\join.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
len(cnt_pop_v['store_name'])
# Out:
# 475

# %%
join_mean = cnt_pop_v.groupby(['store_name']).mean()

# %%
join_mean.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\q-gis\join_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %% [markdown]
# # cluster 파일 분리

# %%
import pandas as pd

# %%
kmeans5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\kmenas_pop_road.csv", encoding="EUC-KR")
kmeans5_group0 = kmeans5['cluster'] == 0
kmeans5_group0 = kmeans5[kmeans5_group0]
kmeans5_group0.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\kmeans5_group0.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
agg_cluster_group1 = agg_cluster5['cluster'] == 1
agg_cluster_group1 = agg_cluster5[agg_cluster_group1]
agg_cluster_group1.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\agg_cluster_group1.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
agg_cluster_group2 = agg_cluster5['cluster'] == 2
agg_cluster_group2 = agg_cluster5[agg_cluster_group2]
agg_cluster_group2.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\agg_cluster_group2.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
agg_cluster_group3 = agg_cluster5['cluster'] == 3
agg_cluster_group3 = agg_cluster5[agg_cluster_group3]
agg_cluster_group3.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\agg_cluster_group3.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
agg_cluster_group4 = agg_cluster5['cluster'] == 4
agg_cluster_group4 = agg_cluster5[agg_cluster_group4]
agg_cluster_group4.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\agg_cluster_group4.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %% [markdown]
# # 도로 + 통행속도 결합

# %%
weekday = v['요일'] == ('월' or '화' or '수' or '목' or '금')
v_weekday = v[weekday]

# %%
v_weekday
# Out:
#               일자 요일    도로명       링크아이디         시점명         종점명  방향    거리  차선수  \
# 20136   20210705  월  4.19로  1080012200     아카데미하우스    국립4.19묘지  상행  1179    1
# 20137   20210705  월  4.19로  1080012800    국립4.19묘지  국립4.19묘지입구  상행   352    2
# 20138   20210705  월  4.19로  1080012700  국립4.19묘지입구    국립4.19묘지  하행   354    2
# 20139   20210705  월  4.19로  1080012100    국립4.19묘지     아카데미하우스  하행  1190    1
# 20140   20210705  월    가락로  1230024700        방이초교      방이동고분군  상행   844    1
# ...          ... ..    ...         ...         ...         ...  ..   ...  ...
# 130874  20210726  월    흑석로  1190003703       중앙대학교        성심의집  하행   398    0
# 130875  20210726  월    흑석로  1190003702        성심의집        이화빌라  하행   143    0
# 130876  20210726  월    흑석로  1190003701        이화빌라        이화약국  하행   133    0
# 130877  20210726  월   희우정로  1130016400      망원정사거리      한강공원입구  상행   692    2
# 130878  20210726  월   희우정로  1130016300      한강공원입구      망원정사거리  하행   688    2
#
# ...

# %%
weekend = v['요일'] == ('토' or '일')
v_weekend = v[weekend]

# %%
v_weekend
# Out:
#               일자 요일    도로명       링크아이디         시점명         종점명  방향    거리  차선수  \
# 10068   20210703  토  4.19로  1080012200     아카데미하우스    국립4.19묘지  상행  1179    1
# 10069   20210703  토  4.19로  1080012800    국립4.19묘지  국립4.19묘지입구  상행   352    2
# 10070   20210703  토  4.19로  1080012700  국립4.19묘지입구    국립4.19묘지  하행   354    2
# 10071   20210703  토  4.19로  1080012100    국립4.19묘지     아카데미하우스  하행  1190    1
# 10072   20210703  토    가락로  1230024700        방이초교      방이동고분군  상행   844    1
# ...          ... ..    ...         ...         ...         ...  ..   ...  ...
# 156042  20210731  토    흑석로  1190003703       중앙대학교        성심의집  하행   398    0
# 156043  20210731  토    흑석로  1190003702        성심의집        이화빌라  하행   143    0
# 156044  20210731  토    흑석로  1190003701        이화빌라        이화약국  하행   133    0
# 156045  20210731  토   희우정로  1130016400      망원정사거리      한강공원입구  상행   692    2
# 156046  20210731  토   희우정로  1130016300      한강공원입구      망원정사거리  하행   688    2
#
# ...

# %%
v_weekday
v_weekday = v_weekday.groupby(['링크아이디']).mean()

# %%
v_weekend = v_weekend.groupby(['링크아이디']).mean()

# %%
v_weekday
v_weekday.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\weekday_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
v_weekend.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\weekend_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
v_weekday
# Out:
#                     일자     거리  차선수      01시      02시      03시      04시  \
# 링크아이디
# 1000000100  20210715.5  306.0  4.0  27.2975  26.3925  26.3150  30.2900
# 1000000200  20210715.5  302.0  3.0  36.6850  37.9450  39.7825  41.6275
# 1000000300  20210715.5  325.0  4.0  15.8225  16.5800  14.6550  16.4500
# 1000000400  20210715.5  325.0  4.0  18.2800  19.1575  18.7350  18.9400
# 1000000500  20210715.5  415.0  4.0  31.4975  32.2750  34.4475  35.0925
# ...                ...    ...  ...      ...      ...      ...      ...
# 3201510100  20210715.5   63.0  2.0  19.2675  19.2025  22.5100  24.1475
# 3201510200  20210715.5  301.0  2.0  24.3475  24.1900  28.6725  24.6625
# 3201510300  20210715.5  308.0  2.0  16.8200  20.9625  21.2750  20.1925
# 3201510600  20210715.5  503.0  1.0  27.0200  29.8900  30.7900  27.8850
# 3201510700  20210715.5  503.0  2.0  25.4750  34.2525  32.0925  37.5150
#
#                 05시      06시      07시  ...      15시      16시      17시  \
# ...

# %%
v_weekend
# Out:
#                   일자   거리  차선수      01시      02시      03시      04시      05시  \
# 링크아이디
# 1000000100  20210717  306    4  25.2575  27.7825  25.6900  28.0750  27.8300
# 1000000200  20210717  302    3  34.1150  34.0200  35.9150  39.8950  36.8150
# 1000000300  20210717  325    4  15.7225  17.0725  15.4825  17.8675  17.5675
# 1000000400  20210717  325    4  17.6725  19.1150  21.5875  21.2825  21.8100
# 1000000500  20210717  415    4  26.9400  27.2475  29.0475  32.3575  34.9625
# ...              ...  ...  ...      ...      ...      ...      ...      ...
# 3201510100  20210717   63    2  20.4300  20.4550  20.7375  21.3000  19.6850
# 3201510200  20210717  301    2  23.8675  19.3275  17.0050  25.4975  20.3150
# 3201510300  20210717  308    2  13.4225  16.9225  20.6025  18.5125  18.1325
# 3201510600  20210717  503    1  27.1125  29.6825  28.2500  30.1175  30.5475
# 3201510700  20210717  503    2  27.2500  28.3850  33.3475  30.8950  28.6500
#
# ...

# %%
road = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\road_extract\road_extract_final.csv", encoding="EUC-KR")

# %%
road
# Out:
#         LINK_ID  begin  end store_name  \
# 0    1110008106      1   13     은평구청입구
# 1    1130019501      1   16        아현역
# 2    1130026401      1    2    상암디지털큐브
# 3    1130026402      1    2      상암DMC
# 4    1130072000      1    2      상암YTN
# ..          ...    ...  ...        ...
# 481  1230029300      1    3      몽촌토성역
# 482  1230028100      1    3    올림픽평화의문
# 483  1230026100      1    3    올림픽공원남문
# 484  1140030700      1    5     신월ICDT
# 485  1140023300      1    3     신월ICDT
#
#                                             store_addr        lat         lot  \
# 0                     서울특별시 은평구 은평로 170 (응암동)1522-3232  37.601042  126.926789
# 1    서울특별시 서대문구 신촌로35길 10 (북아현동, E편한세상신촌 4단지)1522-3232  37.558421  126.956349
# 2                           서울특별시 마포구 상암산로 341522-3232  37.576313  126.889248
# 3    서울특별시 마포구 월드컵북로 375, DMC이안오피스텔1단지 102호,202호 (상...  37.577623  126.890684
# 4                     서울특별시 마포구 상암산로 76 (상암동)1522-3232  37.579183  126.892315
# ...

# %%
road_join_weekday = pd.merge(left=road, right=v_weekday, how='inner', left_on='LINK_ID', right_on='링크아이디')
road_join_weekday.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_join_weekday = road_join_weekday.groupby(['store_name']).mean()
road_join_weekday.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekday_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_join_weekend = pd.merge(left=road, right=v_weekend, how='inner', left_on='LINK_ID', right_on='링크아이디')
road_join_weekday.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_join_weekend = road_join_weekend.groupby(['store_name']).mean()
road_join_weekend.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekend_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %% [markdown]
# # clustering된 데이터에 통행속도(평일/주말) 붙이기

# %%
kmeans5 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\kmeans_5_pop_road.csv", encoding="EUC-KR")

# %%
road_weekday_mean_cluster = pd.merge(left=road_join_weekday, right=kmeans5, how='inner', left_on='store_name', right_on='store_name')

# %%
road_weekday_mean_cluster.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekday_mean_cluster.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_weekend_mean_cluster = pd.merge(left=road_join_weekend, right=kmeans5, how='inner', left_on='store_name', right_on='store_name')

# %%
road_weekend_mean_cluster.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekend_mean_cluster.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_weekday_mean_cluster = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekday_mean_cluster.csv", encoding="EUC-KR")
kmeans5_group0 = road_weekday_mean_cluster['cluster'] == 0
kmeans5_group0 = road_weekday_mean_cluster[kmeans5_group0]
kmeans5_group0.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group0_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group1 = road_weekday_mean_cluster['cluster'] == 1
kmeans5_group1 = road_weekday_mean_cluster[kmeans5_group1]
kmeans5_group1.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group1_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group2 = road_weekday_mean_cluster['cluster'] == 2
kmeans5_group2 = road_weekday_mean_cluster[kmeans5_group2]
kmeans5_group2.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group2_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group3 = road_weekday_mean_cluster['cluster'] == 3
kmeans5_group3 = road_weekday_mean_cluster[kmeans5_group3]
kmeans5_group3.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group3_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group4 = road_weekday_mean_cluster['cluster'] == 4
kmeans5_group4 = road_weekday_mean_cluster[kmeans5_group4]
kmeans5_group4.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group4_weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
road_weekend_mean_cluster = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\road_weekend_mean_cluster.csv", encoding="EUC-KR")
kmeans5_group0_end = road_weekend_mean_cluster['cluster'] == 0
kmeans5_group0_end = road_weekend_mean_cluster[kmeans5_group0_end]
kmeans5_group0_end.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group0_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group1_end = road_weekend_mean_cluster['cluster'] == 1
kmeans5_group1_end = road_weekend_mean_cluster[kmeans5_group1_end]
kmeans5_group1_end.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group1_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group2_end = road_weekend_mean_cluster['cluster'] == 2
kmeans5_group2_end = road_weekend_mean_cluster[kmeans5_group2_end]
kmeans5_group2_end.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group2_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group3_end = road_weekend_mean_cluster['cluster'] == 3
kmeans5_group3_end = road_weekend_mean_cluster[kmeans5_group3_end]
kmeans5_group3_end.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group3_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
kmeans5_group4_end = road_weekend_mean_cluster['cluster'] == 4
kmeans5_group4_end = road_weekend_mean_cluster[kmeans5_group4_end]
kmeans5_group4_end.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\version2\clustering\group4_weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')
