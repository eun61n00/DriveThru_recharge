# %%
import pandas as pd

# %%
v_7 = pd.read_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\서울시 통행속도\2021년 07월 서울시 차량통행속도.csv', encoding="EUC-KR")

# %%
starbucks_road = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_30_50\starbucks_30_50.csv", encoding="EUC-KR")

# %%
starbucks_road
# Out:
#         LINK_ID store_name                         store_addr        lat  \
# 0    1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 1    1220027800     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2    1220030700    신사역성일빌딩  서울특별시 강남구 강남대로 584 (논현동)1522-3232  37.514132
# 3    1220030600    신사역성일빌딩  서울특별시 강남구 강남대로 584 (논현동)1522-3232  37.514132
# 4    1220024000     국기원사거리  서울특별시 강남구 테헤란로 125 (역삼동)1522-3232  37.499517
# ..          ...        ...                                ...        ...
# 633  1060005100         묵동        서울특별시 중랑구 동일로 952 1522-3232  37.615368
# 634  1060005500         묵동        서울특별시 중랑구 동일로 952 1522-3232  37.615368
# 635  1060015100        중화역    서울특별시 중랑구 봉화산로 35 1,2층1522-3232  37.601709
# 636  1160003800     구로하이엔드                                NaN        NaN
# 637  1220031300    서울세관사거리                                NaN        NaN
#
#             lot    도로            layer  \
# 0    127.022223  강남대로            50m제거
# ...

# %%
starbucks_pop = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_join_pop.csv", encoding="EUC-KR")

# %%
starbucks_pop
# Out:
#     store_name  지역  구로구     동    도로  유동인구_평균        lat         lot
# 0      역삼아레나빌딩  서울  강남구  역삼2동   언주로    52263  37.501087  127.043069
# 1         도곡공원  서울  강남구  역삼2동   도곡로    52263  37.492805  127.041309
# 2        역삼이마트  서울  강남구  역삼2동   역삼로    52263  37.499367  127.048425
# 3       논현역사거리  서울  강남구  논현1동  강남대로    41326  37.510178  127.022223
# 4      신사역성일빌딩  서울  강남구  논현1동  강남대로    41326  37.514132  127.020563
# ..         ...  ..  ...   ...   ...      ...        ...         ...
# 551       사가정역  서울  중랑구  면목7동   면목로    20503  37.579594  127.087966
# 552        상봉역  서울  중랑구  상봉1동   망우로    18510  37.596890  127.086470
# 553      묵동이마트  서울  중랑구   묵1동   동일로    26575  37.613433  127.077484
# 554         묵동  서울  중랑구   묵1동   동일로    26575  37.615368  127.076633
# 555        중화역  서울  중랑구  중화2동  봉화산로    26002  37.601709  127.078411
#
# [556 rows x 8 columns]

# %%
pop_join_road = pd.merge(left=starbucks_road, right=starbucks_pop, how='left', left_on='store_name', right_on='store_name')

# %%
pop_join_road
# Out:
#         LINK_ID store_name                         store_addr      lat_x  \
# 0    1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 1    1220027800     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2    1220030700    신사역성일빌딩  서울특별시 강남구 강남대로 584 (논현동)1522-3232  37.514132
# 3    1220030600    신사역성일빌딩  서울특별시 강남구 강남대로 584 (논현동)1522-3232  37.514132
# 4    1220024000     국기원사거리  서울특별시 강남구 테헤란로 125 (역삼동)1522-3232  37.499517
# ..          ...        ...                                ...        ...
# 633  1060005100         묵동        서울특별시 중랑구 동일로 952 1522-3232  37.615368
# 634  1060005500         묵동        서울특별시 중랑구 동일로 952 1522-3232  37.615368
# 635  1060015100        중화역    서울특별시 중랑구 봉화산로 35 1,2층1522-3232  37.601709
# 636  1160003800     구로하이엔드                                NaN        NaN
# 637  1220031300    서울세관사거리                                NaN        NaN
#
#           lot_x  도로_x            layer  \
# 0    127.022223  강남대로            50m제거
# ...

# %%
pop_join_road.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\pop_join_road.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
v_202107 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\202107_v.csv", encoding="EUC-KR")

# %%
v_202107
# Out:
#               일자 요일    도로명       링크아이디         시점명         종점명  방향    거리  차선수  \
# 0       20210701  목  4.19로  1080012200     아카데미하우스    국립4.19묘지  상행  1179    1
# 1       20210701  목  4.19로  1080012800    국립4.19묘지  국립4.19묘지입구  상행   352    2
# 2       20210701  목  4.19로  1080012700  국립4.19묘지입구    국립4.19묘지  하행   354    2
# 3       20210701  목  4.19로  1080012100    국립4.19묘지     아카데미하우스  하행  1190    1
# 4       20210701  목    가락로  1230024700        방이초교      방이동고분군  상행   844    1
# ...          ... ..    ...         ...         ...         ...  ..   ...  ...
# 156042  20210731  토    흑석로  1190003703       중앙대학교        성심의집  하행   398    0
# 156043  20210731  토    흑석로  1190003702        성심의집        이화빌라  하행   143    0
# 156044  20210731  토    흑석로  1190003701        이화빌라        이화약국  하행   133    0
# 156045  20210731  토   희우정로  1130016400      망원정사거리      한강공원입구  상행   692    2
# 156046  20210731  토   희우정로  1130016300      한강공원입구      망원정사거리  하행   688    2
#
# ...

# %%
pop_join_road2 = pd.merge(left=pop_join_road, right=v_202107, how='left', left_on='LINK_ID', right_on='링크아이디')

# %%
pop_join_road2
# Out:
#           LINK_ID store_name                         store_addr      lat_x  \
# 0      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 1      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 3      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 4      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# ...           ...        ...                                ...        ...
# 19773  1220031300    서울세관사거리                                NaN        NaN
# 19774  1220031300    서울세관사거리                                NaN        NaN
# 19775  1220031300    서울세관사거리                                NaN        NaN
# 19776  1220031300    서울세관사거리                                NaN        NaN
# 19777  1220031300    서울세관사거리                                NaN        NaN
#
#             lot_x  도로_x  layer  \
# 0      127.022223  강남대로  50m제거
# ...

# %%
pop_join_road2.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\pop_join_road2.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
pop_join_road2
# Out:
#           LINK_ID store_name                         store_addr      lat_x  \
# 0      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 1      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 3      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 4      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# ...           ...        ...                                ...        ...
# 19773  1220031300    서울세관사거리                                NaN        NaN
# 19774  1220031300    서울세관사거리                                NaN        NaN
# 19775  1220031300    서울세관사거리                                NaN        NaN
# 19776  1220031300    서울세관사거리                                NaN        NaN
# 19777  1220031300    서울세관사거리                                NaN        NaN
#
#             lot_x  도로_x  layer  \
# 0      127.022223  강남대로  50m제거
# ...

# %%
group_by_07시 = pop_join_road2.groupby('store_name')['07시']

# %%
group_by_07시.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\groupby7.csv', sep=',', na_rep='NaN', encoding='EUC-KR')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-a24ba61b7339> in <module>
# ----> 1 group_by_07시.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\groupby7.csv', sep=',', na_rep='NaN', encoding='EUC-KR')
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'to_csv'

# %%
pop_join_road2
# Out:
#           LINK_ID store_name                         store_addr      lat_x  \
# 0      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 1      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 3      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 4      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# ...           ...        ...                                ...        ...
# 19773  1220031300    서울세관사거리                                NaN        NaN
# 19774  1220031300    서울세관사거리                                NaN        NaN
# 19775  1220031300    서울세관사거리                                NaN        NaN
# 19776  1220031300    서울세관사거리                                NaN        NaN
# 19777  1220031300    서울세관사거리                                NaN        NaN
#
#             lot_x  도로_x  layer  \
# 0      127.022223  강남대로  50m제거
# ...

# %%
pop_join_road_weekday = pop_join_road2['요일'] == ('월' or '화' or '수' or '목' or '금')

# %%
pop_join_road_weekend = pop_join_road2['요일'] == ('토' or '일')

# %%
pop_join_road_weekend
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 19773    False
# 19774    False
# 19775    False
# 19776    False
# 19777     True
# Name: 요일, Length: 19778, dtype: bool

# %%
pop_join_road2
# Out:
#           LINK_ID store_name                         store_addr      lat_x  \
# 0      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 1      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 2      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 3      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 4      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# ...           ...        ...                                ...        ...
# 19773  1220031300    서울세관사거리                                NaN        NaN
# 19774  1220031300    서울세관사거리                                NaN        NaN
# 19775  1220031300    서울세관사거리                                NaN        NaN
# 19776  1220031300    서울세관사거리                                NaN        NaN
# 19777  1220031300    서울세관사거리                                NaN        NaN
#
#             lot_x  도로_x  layer  \
# 0      127.022223  강남대로  50m제거
# ...

# %%
weekday = pop_join_road2[pop_join_road_weekday]

# %%
weekday
# Out:
#           LINK_ID store_name                         store_addr      lat_x  \
# 4      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 11     1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 18     1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 25     1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 35     1220027800     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# ...           ...        ...                                ...        ...
# 19741  1160003800     구로하이엔드                                NaN        NaN
# 19751  1220031300    서울세관사거리                                NaN        NaN
# 19758  1220031300    서울세관사거리                                NaN        NaN
# 19765  1220031300    서울세관사거리                                NaN        NaN
# 19772  1220031300    서울세관사거리                                NaN        NaN
#
#             lot_x  도로_x  layer  \
# 4      127.022223  강남대로  50m제거
# ...

# %%
weekend = pop_join_road2[pop_join_road_weekend]

# %%
weekend.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\weekend.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
weekday.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\weekday.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
weekday
# Out:
#           LINK_ID store_name                         store_addr      lat_x  \
# 4      1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 11     1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 18     1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 25     1220027900     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# 35     1220027800     논현역사거리  서울특별시 강남구 강남대로 538 (논현동)1522-3232  37.510178
# ...           ...        ...                                ...        ...
# 19741  1160003800     구로하이엔드                                NaN        NaN
# 19751  1220031300    서울세관사거리                                NaN        NaN
# 19758  1220031300    서울세관사거리                                NaN        NaN
# 19765  1220031300    서울세관사거리                                NaN        NaN
# 19772  1220031300    서울세관사거리                                NaN        NaN
#
#             lot_x  도로_x  layer  \
# 4      127.022223  강남대로  50m제거
# ...

# %%
weekday = weekday.groupby(['store_name']).mean()

# %%
weekday.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\weekday_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
weekend = weekend.groupby(['store_name']).mean()

# %%
weekend.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\weekend_mean.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
cluster8 = pd.read_csv(r"G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_cluster8.csv", encoding="EUC-KR")

# %%
starbucks_group0 = cluster8['cluster'] == 0
starbucks_group0 = cluster8[starbucks_group0]
starbucks_group0.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group0.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group1 = cluster8['cluster'] == 1
starbucks_group1 = cluster8[starbucks_group1]
starbucks_group1.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group1.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group2 = cluster8['cluster'] == 2
starbucks_group2 = cluster8[starbucks_group2]
starbucks_group2.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group2.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group3 = cluster8['cluster'] == 3
starbucks_group3 = cluster8[starbucks_group3]
starbucks_group3.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group3.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group4 = cluster8['cluster'] == 4
starbucks_group4 = cluster8[starbucks_group4]
starbucks_group4.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group4.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group5 = cluster8['cluster'] == 5
starbucks_group5 = cluster8[starbucks_group5]
starbucks_group5.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group5.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group6 = cluster8['cluster'] == 6
starbucks_group6 = cluster8[starbucks_group6]
starbucks_group6.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group6.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
starbucks_group7 = cluster8['cluster'] == 7
starbucks_group7 = cluster8[starbucks_group7]
starbucks_group7.to_csv(r'G:\내 드라이브\2021 공공빅데이터 청년인턴\프로젝트\데이터\starbucks_group7.csv', sep=',', na_rep='NaN', encoding='EUC-KR')

# %%
weekday
# Out:
#                  LINK_ID      lat_x       lot_x  유동인구_평균      lat_y  \
# store_name
# KG타워        1.010009e+09  37.563528  126.969144  24141.0  37.563528
# SSG마켓도곡R    1.220014e+09  37.490298  127.054895  30953.0  37.490298
# 가락시장역       1.230010e+09  37.494299  127.121354  37909.0  37.494299
# 가재울뉴타운      1.120008e+09  37.574984  126.916444  20391.0  37.574984
# 강남R         1.220023e+09  37.497711  127.028439  97922.0  37.497711
# ...                  ...        ...         ...      ...        ...
# 화곡동         1.140038e+09  37.540512  126.837241  47359.0  37.540512
# 환구단         1.010010e+09  37.564448  126.979157  24141.0  37.564448
# 황학사거리       1.018018e+09  37.567644  127.023697  30053.0  37.567644
# 황학캐슬        1.010019e+09  37.571240  127.022905  12939.0  37.571240
# 효창공원앞역      1.020014e+09  37.539305  126.963060  10216.0  37.539305
#
#                  lot_y          일자         링크아이디      거리       차선수  ...  \
# ...

# %%
cluster8 = pd.merge(left=cluster8, right=weekday, how='left', left_on='store_name', right_on='store_name')

# %%
weekday_cluster
# Out:
#     store_name  유동인구_평균_x     차선수_x  cluster       LINK_ID      lat_x  \
# 0         KG타워    24141.0  4.000000        7  1.010009e+09  37.563528
# 1     SSG마켓도곡R    30953.0  4.000000        7  1.220014e+09  37.490298
# 2        가락시장역    37909.0  2.666667        1  1.230010e+09  37.494299
# 3       가재울뉴타운    20391.0  2.000000        5  1.120008e+09  37.574984
# 4          강남R    97922.0  4.000000        2  1.220023e+09  37.497711
# ..         ...        ...       ...      ...           ...        ...
# 288        화곡동    47359.0  3.000000        3  1.140038e+09  37.540512
# 289        환구단    24141.0  3.000000        6  1.010010e+09  37.564448
# 290      황학사거리    30053.0  1.600000        5  1.018018e+09  37.567644
# 291       황학캐슬    12939.0  2.000000        5  1.010019e+09  37.571240
# 292     효창공원앞역    10216.0  3.000000        6  1.020014e+09  37.539305
#
#           lot_x  유동인구_평균_y      lat_y       lot_y  ...       15시       16시  \
# ...
